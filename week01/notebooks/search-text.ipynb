# %%
import os

# %%
def foundText(word, dir):
    results = {}
    
    # Search in all archivesin the dir
    for files in os.listdir(dir):
        if files.endswith(".txt"):  # Only txt
            ruta_files = os.path.join(dir, files)
            with open(ruta_files, "r", encoding="utf-8") as f:
                line_concidences = []
                total_text = 0
                for num_line, linea in enumerate(f, start=1):
                    if word in linea:
                        line_concidences.append(num_line)
                        total_text += linea.count(word)
                if line_concidences:
                    results[files] = {"lineas": line_concidences, "total_text": total_text}
    
    return results

# %%
def main():
    # Dir entered by me
    dir = r"D:\Kevin\Documents\EPN\2024A\Recuperación de Información\ir24a\week01\data"

    word_to_search = input("Enter text to search: ")

    results = foundText(word_to_search, dir)

    if results:
        print("The word '{}' appears in the next files:".format(word_to_search))
        for files, info in results.items():
            print("- files: {}".format(files))
            #print("  Lineas con coincidencia:", info["lineas"])
            print("  Total coincidences:", info["total_text"])
            print()
    else:
        print("The word '{}'dosen't appear in any of the files.".format(word_to_search))

if __name__ == "__main__":
    main()
# Out:
# Enter text to search: hi
# The word 'hi' appears in the next files:
# - files: pg100.txt
#   Total coincidences: 33181
#
# - files: pg10676.txt
#   Total coincidences: 4797
#
# - files: pg1080.txt
#   Total coincidences: 193
#
# - files: pg10907.txt
#   Total coincidences: 7591
#
# - files: pg11.txt
#   Total coincidences: 851
#
# - files: pg1184.txt
#   Total coincidences: 18790
#
# - files: pg120.txt
#   Total coincidences: 2365
#
# - files: pg1232.txt
#   Total coincidences: 2376
#
# - files: pg12582.txt
#   Total coincidences: 8876
#
# - files: pg1259.txt
#   Total coincidences: 9756
#
# - files: pg1260.txt
#   Total coincidences: 5456
#
# - files: pg1342.txt
#   Total coincidences: 4644
#
# - files: pg1400.txt
#   Total coincidences: 6670
#
# - files: pg145.txt
#   Total coincidences: 14229
#
# - files: pg1513.txt
#   Total coincidences: 855
#
# - files: pg16.txt
#   Total coincidences: 1920
#
# - files: pg16389.txt
#   Total coincidences: 2424
#
# - files: pg1661.txt
#   Total coincidences: 4155
#
# - files: pg1727.txt
#   Total coincidences: 5493
#
# - files: pg174.txt
#   Total coincidences: 3392
#
# - files: pg18893.txt
#   Total coincidences: 12532
#
# - files: pg1952.txt
#   Total coincidences: 245
#
# - files: pg1998.txt
#   Total coincidences: 4332
#
# - files: pg2000.txt
#   Total coincidences: 1703
#
# - files: pg20228.txt
#   Total coincidences: 5193
#
# - files: pg205.txt
#   Total coincidences: 4150
#
# - files: pg21012.txt
#   Total coincidences: 6544
#
# - files: pg2160.txt
#   Total coincidences: 6564
#
# - files: pg21700.txt
#   Total coincidences: 4699
#
# - files: pg219.txt
#   Total coincidences: 1545
#
# - files: pg244.txt
#   Total coincidences: 2018
#
# - files: pg25344.txt
#   Total coincidences: 3755
#
# - files: pg2542.txt
#   Total coincidences: 924
#
# - files: pg2554.txt
#   Total coincidences: 8304
#
# - files: pg2591.txt
#   Total coincidences: 3950
#
# - files: pg2600.txt
#   Total coincidences: 25276
#
# - files: pg26073.txt
#   Total coincidences: 6153
#
# - files: pg2641.txt
#   Total coincidences: 2105
#
# - files: pg2701.txt
#   Total coincidences: 9542
#
# - files: pg27827.txt
#   Total coincidences: 2022
#
# - files: pg28054.txt
#   Total coincidences: 14149
#
# - files: pg2814.txt
#   Total coincidences: 2889
#
# - files: pg2852.txt
#   Total coincidences: 2534
#
# - files: pg29728.txt
#   Total coincidences: 2038
#
# - files: pg30254.txt
#   Total coincidences: 5199
#
# - files: pg3207.txt
#   Total coincidences: 7639
#
# - files: pg345.txt
#   Total coincidences: 5959
#
# - files: pg35899.txt
#   Total coincidences: 550
#
# - files: pg37106.txt
#   Total coincidences: 5921
#
# - files: pg394.txt
#   Total coincidences: 2120
#
# - files: pg408.txt
#   Total coincidences: 2505
#
# - files: pg4085.txt
#   Total coincidences: 9206
#
# - files: pg41070.txt
#   Total coincidences: 8248
#
# - files: pg41287.txt
#   Total coincidences: 2752
#
# - files: pg41445.txt
#   Total coincidences: 2411
#
# - files: pg42933.txt
#   Total coincidences: 4162
#
# - files: pg43.txt
#   Total coincidences: 1013
#
# - files: pg4300.txt
#   Total coincidences: 9506
#
# - files: pg44388.txt
#   Total coincidences: 2585
#
# - files: pg44837.txt
#   Total coincidences: 23313
#
# - files: pg45.txt
#   Total coincidences: 2783
#
# - files: pg45540.txt
#   Total coincidences: 3843
#
# - files: pg45848.txt
#   Total coincidences: 4023
#
# - files: pg46.txt
#   Total coincidences: 1344
#
# - files: pg47312.txt
#   Total coincidences: 16733
#
# - files: pg47629.txt
#   Total coincidences: 3823
#
# - files: pg47948.txt
#   Total coincidences: 8526
#
# - files: pg48191.txt
#   Total coincidences: 6511
#
# - files: pg50038.txt
#   Total coincidences: 4517
#
# - files: pg514.txt
#   Total coincidences: 5776
#
# - files: pg5197.txt
#   Total coincidences: 8939
#
# - files: pg5200.txt
#   Total coincidences: 1329
#
# - files: pg52281.txt
#   Total coincidences: 689
#
# - files: pg52882.txt
#   Total coincidences: 4411
#
# - files: pg55.txt
#   Total coincidences: 1146
#
# - files: pg59468.txt
#   Total coincidences: 27320
#
# - files: pg59469.txt
#   Total coincidences: 19241
#
# - files: pg600.txt
#   Total coincidences: 1389
#
# - files: pg6130.txt
#   Total coincidences: 8159
#
# - files: pg61419.txt
#   Total coincidences: 6164
#
# - files: pg62119.txt
#   Total coincidences: 4744
#
# - files: pg64317.txt
#   Total coincidences: 1796
#
# - files: pg6593.txt
#   Total coincidences: 17365
#
# - files: pg67098.txt
#   Total coincidences: 958
#
# - files: pg6761.txt
#   Total coincidences: 9474
#
# - files: pg67979.txt
#   Total coincidences: 2078
#
# - files: pg73442.txt
#   Total coincidences: 589
#
# - files: pg73444.txt
#   Total coincidences: 910
#
# - files: pg73447.txt
#   Total coincidences: 1318
#
# - files: pg73448.txt
#   Total coincidences: 988
#
# - files: pg7370.txt
#   Total coincidences: 2396
#
# - files: pg74.txt
#   Total coincidences: 2818
#
# - files: pg76.txt
#   Total coincidences: 3460
#
# - files: pg768.txt
#   Total coincidences: 4321
#
# - files: pg84.txt
#   Total coincidences: 2521
#
# - files: pg844.txt
#   Total coincidences: 579
#
# - files: pg8800.txt
#   Total coincidences: 3802
#
# - files: pg98.txt
#   Total coincidences: 5723
#
# - files: pg996.txt
#   Total coincidences: 18409
